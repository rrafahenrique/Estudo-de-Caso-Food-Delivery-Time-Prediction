# %%
# Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import utils.funcoes as func

import warnings
warnings.filterwarnings('ignore')

# %%
# Importanto o dataset de treino
df_treino = pd.read_csv('data/data_modelo.csv', sep = ',')

display(df_treino)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 41468  1178   RANCHIRES16DEL01                   35                      4.2
# 41469  7C09      JAPRES04DEL01                   30                      4.8
# 41470  4F8D     CHENRES08DEL03                   30                      4.9
# 41471  5EEE    COIMBRES11DEL01                   20                      4.7
# 41472  5FB2   RANCHIRES09DEL02                   23                      4.9
#
# ...

# %%
func.descricão(df_treino)
# Out:
# <style type="text/css">
# #T_9aa75 th {
#   background-color: #0d253f;
#   color: white;
#   text-align: center;
#   font-size: 12px;
# }
# ...

# %%
df_treino.groupby('Type_of_order')['Distance'].mean()
# Out:
# Type_of_order
# Buffet     9.677144
# Drinks     9.710204
# Meal       9.657065
# Snack      9.806712
# Name: Distance, dtype: float64

# %%
df_treino.groupby('Type_of_order')['Distance'].value_counts()
# Out:
# Type_of_order  Distance
# Buffet         20.166224    12
#                6.114789     10
#                16.710790    10
#                1.551605      9
#                9.307453      9
#                             ..
# Snack          20.955489     1
#                20.955669     1
#                20.955724     1
#                20.955880     1
#                20.956324     1
# Name: count, Length: 14074, dtype: int64

# %%
df_treino.Distance.mean()
# Out:
# np.float64(9.713154043356681)

# %%
df_treino.groupby('Type_of_order')['Distance'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Type_of_order'>
